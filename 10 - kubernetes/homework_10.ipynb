# %% [markdown]
# ### **Question 1**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 2**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Question 4**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Testing the service**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The same result was obtained as in question 1.

# %% [markdown]
# ### **Question 8 (Optional)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After running the script and monitoring the HPA, check the maximum number of replicas reached during the test.
#
# If the CPU load increases enough, the HPA will scale the deployment. You should see the number of replicas increase to match the CPU load, but it will be limited by the --max=3 setting.
# The maximum number of replicas should be 3, assuming the CPU usage was high enough to trigger scaling.
# So, the answer to Question 8 is:
#
# 3 replicas
